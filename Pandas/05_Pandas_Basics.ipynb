# %%
# IMPORT ALL THE REQUIRED MODULES
import warnings
warnings.simplefilter(action='ignore',category=FutureWarning)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('cars.csv',encoding='latin-1')
dataset.head(5)
# Out:
#    Unnamed: 0       brand    model  price (eur)                     engine  \
# 0           0        SEAT    Ibiza         8990      SC 1.2 TSI 90cv Style
# 1           1     Hyundai      i30         9990       1.6 CRDi 110cv Tecno
# 2           2         BMW  Serie 5        13490               530d Touring
# 3           3  Volkswagen     Golf        24990  GTI 2.0 TSI 169kW (230CV)
# 4           4        Opel    Corsa        10460       1.4 Expression 90 CV
#
#    year  mileage (kms)      fuel     gearbox    location
# 0  2016          67000  Gasolina      Manual  Granollers
# 1  2014         104868   DiÃ©sel      Manual  Viladecans
# 2  2011         137566   DiÃ©sel  Automatica  Viladecans
# 3  2018          44495  Gasolina      Manual  Viladecans
# 4  2016          69800  Gasolina      Manual  Sabadell 1

# %% [markdown]
# # groupby()

# %%
brands=dataset.groupby('brand')

# %%
brands

# %%
len(dataset)
# Out:
# 792

# %%
len(brands)
# Out:
# 36

# %%
brands.size().sort_values(ascending=False)
# Out:
# brand
# SEAT          84
# Ford          60
# BMW           57
# Volkswagen    51
# Peugeot       48
# Audi          44
# Citroen       42
# Toyota        42
# Kia           39
# Renault       39
# Nissan        37
# Mercedes      36
# Opel          31
# Hyundai       23
# Fiat          22
# Mini          20
# Mazda         18
# Dacia         14
# Jeep          12
# Land          11
# Mitsubishi     9
# Abarth         9
# Jaguar         6
# Honda          6
# Alfa           4
# Porsche        4
# Suzuki         4
# Volvo          4
# Lexus          3
# Smart          3
# Skoda          2
# Ssangyong      2
# Subaru         2
# Cupra          2
# DS             1
# Chevrolet      1
# dtype: int64

# %%
brands.first()
# Out:
#             Unnamed: 0                  model  price (eur)  \
# brand
# Abarth             140                    500        16990
# Alfa               103        Romeo Giulietta         7670
# Audi                38                     A4        16490
# BMW                  2                Serie 5        13490
# Chevrolet          679                  Cruze         6490
# Citroen             15              C4 Cactus         9990
# Cupra              384                  Ateca        31990
# DS                 574                   DS 4         8790
# Dacia               23                 Duster        12880
# Fiat                11                 DoblÃ²         9990
# Ford                14                  Focus        14490
# Honda              231                   CR-V        16210
# Hyundai              1                    i30         9990
# Jaguar             127                 F-Pace        26990
# Jeep                 6               Wrangler        23990
# ...

# %%
brands.last()
# Out:
#             Unnamed: 0                     model  price (eur)  \
# brand
# Abarth             789                       500        17990
# Alfa               766           Romeo Giulietta        11790
# Audi               765                        A1        10890
# BMW                771                   Serie 4        32990
# Chevrolet          679                     Cruze         6490
# Citroen            779                        C2         4990
# Cupra              465                 Formentor        27990
# DS                 574                      DS 4         8790
# Dacia              791                    Dokker        14390
# Fiat               769                      500X        15490
# Ford               786                     Focus        15990
# Honda              601                      CR-V        14990
# Hyundai            785                    Tucson        15990
# Jaguar             544                        XF        10990
# ...

# %%
d=brands.groups   # if a row belongs to a group its location is returned
for k in d:
    print(k,d[k])
# Out:
# Abarth Int64Index([140, 500, 557, 624, 628, 659, 699, 772, 789], dtype='int64')
# Alfa Int64Index([103, 543, 560, 766], dtype='int64')
# Audi Int64Index([ 38,  73,  91,  93,  98, 108, 118, 160, 177, 187, 199, 245, 248,
#             251, 282, 304, 317, 357, 389, 390, 398, 400, 404, 451, 485, 490,
#             512, 575, 579, 584, 596, 629, 658, 661, 667, 669, 688, 694, 702,
#             720, 735, 741, 758, 765],
#            dtype='int64')
# BMW Int64Index([  2,  12,  20,  27,  37,  54,  71,  72,  82, 137, 150, 176, 200,
#             223, 224, 236, 237, 263, 303, 309, 311, 312, 315, 326, 328, 332,
#             371, 474, 482, 494, 495, 513, 524, 553, 562, 563, 578, 582, 592,
#             605, 612, 623, 630, 637, 654, 663, 670, 680, 682, 683, 696, 701,
#             709, 732, 740, 743, 771],
#            dtype='int64')
# Chevrolet Int64Index([679], dtype='int64')
# Citroen Int64Index([ 15,  30,  42,  63,  78,  97, 116, 126, 130, 136, 243, 253, 255,
# ...

# %%
dataset.iloc[3,:]
# Out:
# Unnamed: 0                               3
# brand                           Volkswagen
# model                                 Golf
# price (eur)                          24990
# engine           GTI 2.0 TSI 169kW (230CV)
# year                                  2018
# mileage (kms)                        44495
# fuel                              Gasolina
# gearbox                             Manual
# location                        Viladecans
# Name: 3, dtype: object

# %%
brands.get_group('Volvo')
# Out:
#      Unnamed: 0  brand model  price (eur)                    engine  year  \
# 96           96  Volvo   V40        15990           2.0 T2 Momentum  2018
# 360         360  Volvo  XC40        28990      1.5 T2 Momentum Core  2021
# 395         395  Volvo   V40        13490             1.6 D2 Summum  2014
# 450         450  Volvo  XC40        28490  2.0 D4 AWD Momentum Auto  2018
#
#      mileage (kms)      fuel     gearbox    location
# 96           76086  Gasolina      Manual  Viladecans
# 360           6000  Gasolina      Manual  Sabadell 3
# 395          61987   DiÃ©sel      Manual  Viladecans
# 450         128000   DiÃ©sel  Automatica  Sabadell 3

# %%
brands.get_group('Volvo').shape
# Out:
# (4, 10)

# %%
brands.sum()
# Out:
#             Unnamed: 0  price (eur)    year  mileage (kms)
# brand
# Abarth            5368       147200   18150         520724
# Alfa              1972        37440    8056         337125
# Audi             18686       800460   88678        4943422
# BMW              23773      1235040  114911        6320608
# Chevrolet          679         6490    2011          97806
# Citroen          15976       487060   84681        3247586
# Cupra              849        59980    4040          36308
# DS                 574         8790    2015          91700
# Dacia             5942       146500   28232         667947
# Fiat              8655       241710   44386        1655825
# Ford             23710       828590  121031        3978244
# Honda             2514       116660   12094         532129
# Hyundai           9386       354870   46386        1659109
# Jaguar            1915       166940   12096         448239
# Jeep              4069       245930   24196         854243
# ...

# %%
brands.mean()
# Out:
#             Unnamed: 0   price (eur)         year  mileage (kms)
# brand
# Abarth      596.444444  16355.555556  2016.666667   57858.222222
# Alfa        493.000000   9360.000000  2014.000000   84281.250000
# Audi        424.681818  18192.272727  2015.409091  112350.500000
# BMW         417.070175  21667.368421  2015.982456  110887.859649
# Chevrolet   679.000000   6490.000000  2011.000000   97806.000000
# Citroen     380.380952  11596.666667  2016.214286   77323.476190
# Cupra       424.500000  29990.000000  2020.000000   18154.000000
# DS          574.000000   8790.000000  2015.000000   91700.000000
# Dacia       424.428571  10464.285714  2016.571429   47710.500000
# Fiat        393.409091  10986.818182  2017.545455   75264.772727
# Ford        395.166667  13809.833333  2017.183333   66304.066667
# Honda       419.000000  19443.333333  2015.666667   88688.166667
# Hyundai     408.086957  15429.130435  2016.782609   72135.173913
# ...

# %%
brands['price (eur)'].mean().sort_values(ascending=False)
# Out:
# brand
# Cupra         29990.000000
# Jaguar        27823.333333
# Porsche       27712.500000
# Land          26490.000000
# Mercedes      23732.777778
# Volvo         21740.000000
# BMW           21667.368421
# Subaru        21320.000000
# Jeep          20494.166667
# Honda         19443.333333
# Lexus         18990.000000
# Audi          18192.272727
# Volkswagen    16747.843137
# Mazda         16495.000000
# Abarth        16355.555556
# Kia           15478.461538
# Toyota        15468.095238
# Mini          15461.500000
# Hyundai       15429.130435
# SEAT          14828.452381
# Mitsubishi    14656.666667
# Suzuki        14240.000000
# Peugeot       13979.166667
# Ford          13809.833333
# Nissan        13790.810811
# Renault       13736.153846
# Opel          12419.032258
# Ssangyong     11840.000000
# Smart         11823.333333
# Citroen       11596.666667
# Fiat          10986.818182
# Dacia         10464.285714
# Alfa           9360.000000
# DS             8790.000000
# ...

# %%
dataset
# Out:
#      Unnamed: 0       brand     model  price (eur)  \
# 0             0        SEAT     Ibiza         8990
# 1             1     Hyundai       i30         9990
# 2             2         BMW   Serie 5        13490
# 3             3  Volkswagen      Golf        24990
# 4             4        Opel     Corsa        10460
# ..          ...         ...       ...          ...
# 787         787  Volkswagen      Golf        13990
# 788         788         Kia  Sportage        24990
# 789         789      Abarth       500        17990
# 790         790  Volkswagen    Tiguan        14990
# 791         791       Dacia    Dokker        14390
#
#                                        engine  year  mileage (kms)      fuel  \
# 0                       SC 1.2 TSI 90cv Style  2016          67000  Gasolina
# 1                        1.6 CRDi 110cv Tecno  2014         104868   DiÃ©sel
# 2                                530d Touring  2011         137566   DiÃ©sel
# ...

# %%
brands=dataset.groupby('brand')
brands['mileage (kms)'].median().plot.bar()
# Out:
# <AxesSubplot:xlabel='brand'>

# %% [markdown]
# # unique()
#     It will print all the unique values in that column

# %%
len(dataset['model'].unique())  # in total dataset length of 792 , 206 unique models are present
# Out:
# 206

# %%
dataset.head(10)
# Out:
#    Unnamed: 0       brand                  model  price (eur)  \
# 0           0        SEAT                  Ibiza         8990
# 1           1     Hyundai                    i30         9990
# 2           2         BMW                Serie 5        13490
# 3           3  Volkswagen                   Golf        24990
# 4           4        Opel                  Corsa        10460
# 5           5        SEAT                  Ibiza         8490
# 6           6        Jeep               Wrangler        23990
# 7           7         Kia               Sportage        14990
# 8           8        Land  Rover Discovery Sport        19490
# 9           9        SEAT                   Leon        21990
#
#                                     engine  year  mileage (kms)      fuel  \
# 0                    SC 1.2 TSI 90cv Style  2016          67000  Gasolina
# 1                     1.6 CRDi 110cv Tecno  2014         104868   DiÃ©sel
# ...

# %%
modelgroup=dataset.groupby('model')

# %%
modelgroup

# %%
temp=modelgroup['engine'].max()
print(temp[0])
# Out:
# Top! Allure 1.2 PureTech 82

# %%
x=brands['engine'].max()
print(x[x<'P'])
# Out:
# brand
# Abarth            595 Turismo 1.4 16v T-Jet 160cv E6
# Alfa                       1.6 JTDm 120cv Collezione
# Chevrolet                                     1.6 LS
# Cupra         2.0 TSI 221kW (300CV) 4Drive DSG St&Sp
# DS                               1.6 HDi 90cv Design
# Honda                              2.2 i-DTEC Innova
# Jaguar                   3.0L TDV6 AWD AutomÃ¡tico S
# Jeep              Limited 1.3G 112kW (150CV) 4x2 DCT
# Land                2.2L TD4 150CV 4x4 Prestige Auto
# Lexus                              2.5 300h Business
# Mazda              2.2 DE AT 4WD L+P+ T.+SR (CN) WGN
# Mini                                             One
# Mitsubishi                      220 DI-D SST Kaiteki
# Skoda                            1.2 TSI 90cv Active
# Smart                      60kW(81CV) electric drive
# Ssangyong                            G16 Limited 4x2
# Subaru                2.0i Hybrid CVT Executive Plus
# Suzuki                         1.6 DDiS GLX 4WD TCSS
# ...
